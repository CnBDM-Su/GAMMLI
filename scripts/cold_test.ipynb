# %% [markdown]
# ## Regression

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from collections import OrderedDict
import time
from sklearn.metrics import mean_squared_error,roc_auc_score,mean_absolute_error,log_loss
import sys
sys.path.append('benchmark/')
from gammli_test import gammli
from xgb_test import xgb
from svd_test import svd
from deepfm_fm_test import deepfm_fm
sys.path.append('../')
from gammli.GAMMLI import GAMMLI
from gammli.DataReader import data_initialize

import tensorflow as tf
tf.compat.v1.enable_eager_execution()
random_state = 0
data= pd.read_csv('data/simulation/simulation_regression.csv')
task_type = "Regression"

meta_info = OrderedDict()

meta_info['uf_1']={'type': 'continues','source':'user'}
meta_info['uf_2']={'type': 'continues','source':'user'}
meta_info['uf_3']={'type': 'continues','source':'user'}
meta_info['uf_4']={'type': 'continues','source':'user'}
meta_info['uf_5']={'type': 'continues','source':'user'}
meta_info['if_1']={'type': 'continues','source':'item'}
meta_info['if_2']={'type': 'continues','source':'item'}
meta_info['if_3']={'type': 'continues','source':'item'}
meta_info['if_4']={'type': 'continues','source':'item'}
meta_info['if_5']={'type': 'continues','source':'item'}
meta_info['user_id']={"type":"id",'source':'user'}
meta_info['item_id']={"type":"id",'source':'item'}
meta_info['target']={"type":"target",'source':''}
#the best shrinkage is 0.917120
#the best combination is 0.600000
lx_params = {
        "rank":3,
        "main_effect_epochs":300,
        "interaction_epochs" : 200 ,
        "tuning_epochs" : 50 , 
        "mf_training_iters": 200,
        "u_group_num":30,
        "i_group_num":50,
        "auto_tune":False,
        "best_shrinkage":1,
        "best_combination":0.4,
        "verbose":False
    }

deepfm_fm_params = {
        "epochs":500,
        "loss_type" : 'mse' ,
        "eval_metric" : mean_absolute_error , 
        "greater_is_better": False,
        "verbose":True,
        "early_stopping": True
    }

# %%
result_gammli = gammli('cold',data, meta_info,task_type , random_state=0, params=lx_params)
result_deepfm, result_fm = deepfm_fm('cold',data, meta_info,task_type , random_state=0, params=deepfm_fm_params)
result_sim_re = pd.concat([result_gammli,result_deepfm,result_fm],0)

result_sim_re.to_csv('result/cold_test/reg_cold_start.csv',index=None)
# Out:
# ..\gammli\DataReader.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df[col] = df[col].astype(np.float16)
# Memory usage of dataframe is 0.86 MB
# Memory usage after optimization is: 0.26 MB
# Decreased by 69.6%
# Memory usage of dataframe is 0.21 MB
# Memory usage after optimization is: 0.07 MB
# Decreased by 69.6%
# test cold start user: 0
# test cold start item: 3
# validation cold start user: 0
# validation cold start item: 1
# 0
# ..\gammli\DataReader.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df[col] = df[col].astype(np.float16)
# ListWrapper(['uf_1', 'uf_2', 'uf_3', 'uf_4', 'uf_5', 'if_1', 'if_2', 'if_3', 'if_4', 'if_5'])
# time cost: 38.840643882751465
# After the gam stage, training error is 0.03142 , validation error is 0.03139
# missing value counts: 92783
# #####mf_training#####
# C:\Users\64161\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3118: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\64161\Anaconda3\lib\site-packages\numpy\core\_methods.py:78: RuntimeWarning: invalid value encountered in true_divide
#   ret, rcount, out=ret, casting='unsafe', subok=False)
# C:\Users\64161\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3118: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\64161\Anaconda3\lib\site-packages\numpy\core\_methods.py:78: RuntimeWarning: invalid value encountered in true_divide
#   ret, rcount, out=ret, casting='unsafe', subok=False)
# C:\Users\64161\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3118: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\64161\Anaconda3\lib\site-packages\numpy\core\_methods.py:78: RuntimeWarning: invalid value encountered in true_divide
#   ret, rcount, out=ret, casting='unsafe', subok=False)
# final num of user group: 1
# final num of item group: 1
# change mode state : True
# time cost: 21.048802852630615
# After the matrix factor stage, training error is 0.00918, validation error is 0.02003
# 1
# ..\gammli\DataReader.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df[col] = df[col].astype(np.float16)
# ListWrapper(['uf_1', 'uf_2', 'uf_3', 'uf_4', 'uf_5', 'if_1', 'if_2', 'if_3', 'if_4', 'if_5'])
# time cost: 41.26956534385681
# After the gam stage, training error is 0.03278 , validation error is 0.03564
# missing value counts: 92783
# #####mf_training#####
# C:\Users\64161\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3118: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\64161\Anaconda3\lib\site-packages\numpy\core\_methods.py:78: RuntimeWarning: invalid value encountered in true_divide
#   ret, rcount, out=ret, casting='unsafe', subok=False)
# C:\Users\64161\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3118: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\64161\Anaconda3\lib\site-packages\numpy\core\_methods.py:78: RuntimeWarning: invalid value encountered in true_divide
#   ret, rcount, out=ret, casting='unsafe', subok=False)
# C:\Users\64161\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3118: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\64161\Anaconda3\lib\site-packages\numpy\core\_methods.py:78: RuntimeWarning: invalid value encountered in true_divide
#   ret, rcount, out=ret, casting='unsafe', subok=False)
# final num of user group: 1
# final num of item group: 1
# change mode state : True
# time cost: 21.903541088104248
# After the matrix factor stage, training error is 0.00834, validation error is 0.02132
# 2
# ..\gammli\DataReader.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df[col] = df[col].astype(np.float16)
# ListWrapper(['uf_1', 'uf_2', 'uf_3', 'uf_4', 'uf_5', 'if_1', 'if_2', 'if_3', 'if_4', 'if_5'])
# time cost: 50.297664642333984
# After the gam stage, training error is 0.03125 , validation error is 0.03315
# missing value counts: 92983
# #####mf_training#####
# C:\Users\64161\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3118: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\64161\Anaconda3\lib\site-packages\numpy\core\_methods.py:78: RuntimeWarning: invalid value encountered in true_divide
#   ret, rcount, out=ret, casting='unsafe', subok=False)
# C:\Users\64161\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3118: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\64161\Anaconda3\lib\site-packages\numpy\core\_methods.py:78: RuntimeWarning: invalid value encountered in true_divide
#   ret, rcount, out=ret, casting='unsafe', subok=False)
# C:\Users\64161\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3118: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\64161\Anaconda3\lib\site-packages\numpy\core\_methods.py:78: RuntimeWarning: invalid value encountered in true_divide
#   ret, rcount, out=ret, casting='unsafe', subok=False)
# final num of user group: 1
# final num of item group: 1
# change mode state : True
# time cost: 22.572071313858032
# After the matrix factor stage, training error is 0.00812, validation error is 0.01883
# benchmark\gammli_test.py:86: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   [(te_Xi[:,1] != 'cold') & (te_Xi[:,0] != 'cold')] != [True]
# no cold samples
# 3
# ..\gammli\DataReader.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df[col] = df[col].astype(np.float16)
# ListWrapper(['uf_1', 'uf_2', 'uf_3', 'uf_4', 'uf_5', 'if_1', 'if_2', 'if_3', 'if_4', 'if_5'])
# time cost: 49.60226631164551
# After the gam stage, training error is 0.03092 , validation error is 0.03253
# missing value counts: 92983
# #####mf_training#####
# C:\Users\64161\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3118: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\64161\Anaconda3\lib\site-packages\numpy\core\_methods.py:78: RuntimeWarning: invalid value encountered in true_divide
#   ret, rcount, out=ret, casting='unsafe', subok=False)
# C:\Users\64161\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3118: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\64161\Anaconda3\lib\site-packages\numpy\core\_methods.py:78: RuntimeWarning: invalid value encountered in true_divide
#   ret, rcount, out=ret, casting='unsafe', subok=False)
# C:\Users\64161\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3118: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\64161\Anaconda3\lib\site-packages\numpy\core\_methods.py:78: RuntimeWarning: invalid value encountered in true_divide
#   ret, rcount, out=ret, casting='unsafe', subok=False)
# final num of user group: 1
# final num of item group: 1
# change mode state : True
# time cost: 21.530133724212646
# After the matrix factor stage, training error is 0.00892, validation error is 0.01987
# benchmark\gammli_test.py:86: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   [(te_Xi[:,1] != 'cold') & (te_Xi[:,0] != 'cold')] != [True]
# no cold samples
# 4
# ..\gammli\DataReader.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df[col] = df[col].astype(np.float16)
# ListWrapper(['uf_1', 'uf_2', 'uf_3', 'uf_4', 'uf_5', 'if_1', 'if_2', 'if_3', 'if_4', 'if_5'])
# time cost: 50.0468966960907
# After the gam stage, training error is 0.03551 , validation error is 0.03537
# missing value counts: 92983
# #####mf_training#####
# C:\Users\64161\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3118: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\64161\Anaconda3\lib\site-packages\numpy\core\_methods.py:78: RuntimeWarning: invalid value encountered in true_divide
#   ret, rcount, out=ret, casting='unsafe', subok=False)
# C:\Users\64161\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3118: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\64161\Anaconda3\lib\site-packages\numpy\core\_methods.py:78: RuntimeWarning: invalid value encountered in true_divide
#   ret, rcount, out=ret, casting='unsafe', subok=False)
# C:\Users\64161\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3118: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\64161\Anaconda3\lib\site-packages\numpy\core\_methods.py:78: RuntimeWarning: invalid value encountered in true_divide
#   ret, rcount, out=ret, casting='unsafe', subok=False)
# final num of user group: 1
# final num of item group: 1
# change mode state : True
# time cost: 23.85073757171631
# After the matrix factor stage, training error is 0.00856, validation error is 0.01972
# benchmark\gammli_test.py:86: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   [(te_Xi[:,1] != 'cold') & (te_Xi[:,0] != 'cold')] != [True]
# no cold samples
# 5
# ..\gammli\DataReader.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df[col] = df[col].astype(np.float16)
# ListWrapper(['uf_1', 'uf_2', 'uf_3', 'uf_4', 'uf_5', 'if_1', 'if_2', 'if_3', 'if_4', 'if_5'])
# time cost: 48.69867920875549
# After the gam stage, training error is 0.03022 , validation error is 0.02823
# missing value counts: 92783
# #####mf_training#####
# C:\Users\64161\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3118: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\64161\Anaconda3\lib\site-packages\numpy\core\_methods.py:78: RuntimeWarning: invalid value encountered in true_divide
#   ret, rcount, out=ret, casting='unsafe', subok=False)
# C:\Users\64161\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3118: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\64161\Anaconda3\lib\site-packages\numpy\core\_methods.py:78: RuntimeWarning: invalid value encountered in true_divide
#   ret, rcount, out=ret, casting='unsafe', subok=False)
# C:\Users\64161\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3118: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\64161\Anaconda3\lib\site-packages\numpy\core\_methods.py:78: RuntimeWarning: invalid value encountered in true_divide
#   ret, rcount, out=ret, casting='unsafe', subok=False)
# final num of user group: 1
# final num of item group: 1
# change mode state : True
# time cost: 23.45894479751587
# After the matrix factor stage, training error is 0.00786, validation error is 0.01594
# 6
# ..\gammli\DataReader.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df[col] = df[col].astype(np.float16)
# ListWrapper(['uf_1', 'uf_2', 'uf_3', 'uf_4', 'uf_5', 'if_1', 'if_2', 'if_3', 'if_4', 'if_5'])
# time cost: 48.36717486381531
# After the gam stage, training error is 0.03334 , validation error is 0.03762
# missing value counts: 92983
# #####mf_training#####
# C:\Users\64161\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3118: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\64161\Anaconda3\lib\site-packages\numpy\core\_methods.py:78: RuntimeWarning: invalid value encountered in true_divide
#   ret, rcount, out=ret, casting='unsafe', subok=False)
# C:\Users\64161\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3118: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\64161\Anaconda3\lib\site-packages\numpy\core\_methods.py:78: RuntimeWarning: invalid value encountered in true_divide
#   ret, rcount, out=ret, casting='unsafe', subok=False)
# final num of user group: 1
# final num of item group: 1
# change mode state : True
# time cost: 23.96419358253479
# After the matrix factor stage, training error is 0.00851, validation error is 0.02268
# benchmark\gammli_test.py:86: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   [(te_Xi[:,1] != 'cold') & (te_Xi[:,0] != 'cold')] != [True]
# no cold samples
# 7
# ..\gammli\DataReader.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df[col] = df[col].astype(np.float16)
# ListWrapper(['uf_1', 'uf_2', 'uf_3', 'uf_4', 'uf_5', 'if_1', 'if_2', 'if_3', 'if_4', 'if_5'])
# time cost: 46.243529081344604
# After the gam stage, training error is 0.03083 , validation error is 0.03172
# missing value counts: 92983
# #####mf_training#####
# C:\Users\64161\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3118: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\64161\Anaconda3\lib\site-packages\numpy\core\_methods.py:78: RuntimeWarning: invalid value encountered in true_divide
#   ret, rcount, out=ret, casting='unsafe', subok=False)
# C:\Users\64161\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3118: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\64161\Anaconda3\lib\site-packages\numpy\core\_methods.py:78: RuntimeWarning: invalid value encountered in true_divide
#   ret, rcount, out=ret, casting='unsafe', subok=False)
# C:\Users\64161\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3118: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\64161\Anaconda3\lib\site-packages\numpy\core\_methods.py:78: RuntimeWarning: invalid value encountered in true_divide
#   ret, rcount, out=ret, casting='unsafe', subok=False)
# C:\Users\64161\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3118: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\64161\Anaconda3\lib\site-packages\numpy\core\_methods.py:78: RuntimeWarning: invalid value encountered in true_divide
#   ret, rcount, out=ret, casting='unsafe', subok=False)
# final num of user group: 1
# final num of item group: 1
# change mode state : True
# time cost: 24.171194076538086
# After the matrix factor stage, training error is 0.00885, validation error is 0.01945
# benchmark\gammli_test.py:86: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   [(te_Xi[:,1] != 'cold') & (te_Xi[:,0] != 'cold')] != [True]
# no cold samples
# 8
# ..\gammli\DataReader.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df[col] = df[col].astype(np.float16)
# ListWrapper(['uf_1', 'uf_2', 'uf_3', 'uf_4', 'uf_5', 'if_1', 'if_2', 'if_3', 'if_4', 'if_5'])
# time cost: 56.79561710357666
# After the gam stage, training error is 0.03033 , validation error is 0.03114
# missing value counts: 92883
# #####mf_training#####
# C:\Users\64161\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3118: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\64161\Anaconda3\lib\site-packages\numpy\core\_methods.py:78: RuntimeWarning: invalid value encountered in true_divide
#   ret, rcount, out=ret, casting='unsafe', subok=False)
# C:\Users\64161\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3118: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\64161\Anaconda3\lib\site-packages\numpy\core\_methods.py:78: RuntimeWarning: invalid value encountered in true_divide
#   ret, rcount, out=ret, casting='unsafe', subok=False)
# C:\Users\64161\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3118: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\64161\Anaconda3\lib\site-packages\numpy\core\_methods.py:78: RuntimeWarning: invalid value encountered in true_divide
#   ret, rcount, out=ret, casting='unsafe', subok=False)
# final num of user group: 1
# final num of item group: 1
# change mode state : True
# time cost: 26.53544282913208
# After the matrix factor stage, training error is 0.00842, validation error is 0.01826
# 9
# ..\gammli\DataReader.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df[col] = df[col].astype(np.float16)
# ListWrapper(['uf_1', 'uf_2', 'uf_3', 'uf_4', 'uf_5', 'if_1', 'if_2', 'if_3', 'if_4', 'if_5'])
# time cost: 42.728649377822876
# After the gam stage, training error is 0.02954 , validation error is 0.02839
# missing value counts: 92783
# #####mf_training#####
# C:\Users\64161\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3118: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\64161\Anaconda3\lib\site-packages\numpy\core\_methods.py:78: RuntimeWarning: invalid value encountered in true_divide
#   ret, rcount, out=ret, casting='unsafe', subok=False)
# C:\Users\64161\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3118: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\64161\Anaconda3\lib\site-packages\numpy\core\_methods.py:78: RuntimeWarning: invalid value encountered in true_divide
#   ret, rcount, out=ret, casting='unsafe', subok=False)
# final num of user group: 1
# final num of item group: 1
# change mode state : True
# time cost: 24.238954067230225
# After the matrix factor stage, training error is 0.00742, validation error is 0.01427
# ..\gammli\DataReader.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df[col] = df[col].astype(np.float16)
# Memory usage of dataframe is 0.86 MB
# Memory usage after optimization is: 0.26 MB
# Decreased by 69.6%
# Memory usage of dataframe is 0.21 MB
# Memory usage after optimization is: 0.07 MB
# Decreased by 69.6%
# test cold start user: 0
# test cold start item: 3
# validation cold start user: 0
# validation cold start item: 1
# ..\gammli\DataReader.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df[col] = df[col].astype(np.float16)
# W0804 14:08:46.283190 26516 deprecation.py:506] From benchmark/deepfm\DeepFM.py:93: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# {'embedding_size': 3, 'deep_layers': [32, 32], 'use_deep': True, 'use_fm': True, 'deep_layers_activation': <function relu at 0x000002001CA752F0>, 'loss_type': 'mse', 'epoch': 300, 'batch_size': 500, 'learning_rate': 0.01, 'optimizer_type': 'adam', 'batch_norm': 0, 'batch_norm_decay': 0.995, 'l2_reg': 0.01, 'greater_is_better': False, 'verbose': True, 'eval_metric': <function mean_absolute_error at 0x000002001B298B70>, 'random_seed': 0, 'feature_size': 1110, 'field_size': 12}
# #params: 6728
# [1] train-result=5.0320, valid-result=5.1507 [0.2 s]
# [2] train-result=3.2856, valid-result=3.3494 [0.1 s]
# [3] train-result=3.3358, valid-result=3.4874 [0.1 s]
# [4] train-result=2.4973, valid-result=2.6865 [0.1 s]
# [5] train-result=2.4690, valid-result=2.7215 [0.1 s]
# [6] train-result=2.1327, valid-result=2.4717 [0.1 s]
# [7] train-result=2.1541, valid-result=2.4991 [0.1 s]
# [8] train-result=2.0304, valid-result=2.4156 [0.1 s]
# [9] train-result=2.1174, valid-result=2.4481 [0.1 s]
# [10] train-result=1.9817, valid-result=2.3559 [0.1 s]
# [11] train-result=2.0708, valid-result=2.4103 [0.1 s]
# [12] train-result=2.0084, valid-result=2.3790 [0.1 s]
# [13] train-result=1.9765, valid-result=2.3592 [0.1 s]
# [14] train-result=1.9456, valid-result=2.3409 [0.1 s]
# [15] train-result=1.9272, valid-result=2.3243 [0.1 s]
# [16] train-result=1.8870, valid-result=2.3014 [0.1 s]
# [17] train-result=1.8769, valid-result=2.2984 [0.1 s]
# [18] train-result=1.8421, valid-result=2.2833 [0.1 s]
# [19] train-result=1.7940, valid-result=2.2649 [0.1 s]
# [20] train-result=1.8115, valid-result=2.2638 [0.1 s]
# [21] train-result=1.7410, valid-result=2.2572 [0.1 s]
# [22] train-result=1.7426, valid-result=2.2311 [0.1 s]
# [23] train-result=1.6618, valid-result=2.1860 [0.1 s]
# [24] train-result=1.6110, valid-result=2.1491 [0.1 s]
# [25] train-result=1.5991, valid-result=2.1286 [0.2 s]
# [26] train-result=1.5738, valid-result=2.1067 [0.1 s]
# [27] train-result=1.5247, valid-result=2.0733 [0.1 s]
# [28] train-result=1.5118, valid-result=2.0484 [0.1 s]
# [29] train-result=1.4649, valid-result=2.0086 [0.1 s]
# [30] train-result=1.4053, valid-result=1.9587 [0.1 s]
# [31] train-result=1.3634, valid-result=1.9032 [0.1 s]
# [32] train-result=1.3326, valid-result=1.8570 [0.1 s]
# [33] train-result=1.2741, valid-result=1.8014 [0.1 s]
# [34] train-result=1.2218, valid-result=1.7451 [0.1 s]
# [35] train-result=1.1679, valid-result=1.6889 [0.1 s]
# [36] train-result=1.1238, valid-result=1.6394 [0.1 s]
# [37] train-result=1.0789, valid-result=1.5886 [0.1 s]
# [38] train-result=1.0301, valid-result=1.5392 [0.1 s]
# [39] train-result=0.9871, valid-result=1.4915 [0.1 s]
# [40] train-result=0.9497, valid-result=1.4508 [0.1 s]
# [41] train-result=0.9068, valid-result=1.4087 [0.1 s]
# [42] train-result=0.8719, valid-result=1.3704 [0.1 s]
# [43] train-result=0.8411, valid-result=1.3348 [0.1 s]
# [44] train-result=0.8237, valid-result=1.3106 [0.1 s]
# [45] train-result=0.7846, valid-result=1.2723 [0.1 s]
# [46] train-result=0.7548, valid-result=1.2454 [0.1 s]
# [47] train-result=0.7273, valid-result=1.2203 [0.1 s]
# [48] train-result=0.7058, valid-result=1.2026 [0.1 s]
# [49] train-result=0.6838, valid-result=1.1846 [0.1 s]
# [50] train-result=0.6667, valid-result=1.1636 [0.1 s]
# [51] train-result=0.6476, valid-result=1.1516 [0.1 s]
# [52] train-result=0.6308, valid-result=1.1353 [0.1 s]
# [53] train-result=0.6147, valid-result=1.1234 [0.1 s]
# [54] train-result=0.6016, valid-result=1.1131 [0.1 s]
# [55] train-result=0.5904, valid-result=1.1020 [0.1 s]
# [56] train-result=0.5801, valid-result=1.0935 [0.1 s]
# [57] train-result=0.5721, valid-result=1.0853 [0.1 s]
# [58] train-result=0.5555, valid-result=1.0778 [0.1 s]
# [59] train-result=0.5475, valid-result=1.0690 [0.1 s]
# [60] train-result=0.5352, valid-result=1.0632 [0.1 s]
# [61] train-result=0.5364, valid-result=1.0645 [0.1 s]
# [62] train-result=0.5158, valid-result=1.0466 [0.1 s]
# [63] train-result=0.5076, valid-result=1.0429 [0.1 s]
# [64] train-result=0.5014, valid-result=1.0376 [0.1 s]
# [65] train-result=0.4922, valid-result=1.0337 [0.1 s]
# [66] train-result=0.4883, valid-result=1.0290 [0.1 s]
# [67] train-result=0.4793, valid-result=1.0266 [0.1 s]
# [68] train-result=0.4775, valid-result=1.0236 [0.1 s]
# [69] train-result=0.4693, valid-result=1.0195 [0.1 s]
# [70] train-result=0.4644, valid-result=1.0159 [0.1 s]
# [71] train-result=0.4614, valid-result=1.0128 [0.1 s]
# [72] train-result=0.4640, valid-result=1.0148 [0.1 s]
# [73] train-result=0.4510, valid-result=1.0064 [0.1 s]
# [74] train-result=0.4556, valid-result=1.0062 [0.1 s]
# [75] train-result=0.4498, valid-result=1.0066 [0.1 s]
# [76] train-result=0.4381, valid-result=1.0009 [0.1 s]
# [77] train-result=0.4352, valid-result=0.9981 [0.1 s]
# [78] train-result=0.4306, valid-result=0.9948 [0.1 s]
# [79] train-result=0.4301, valid-result=0.9939 [0.1 s]
# [80] train-result=0.4262, valid-result=0.9934 [0.1 s]
# [81] train-result=0.4291, valid-result=0.9932 [0.1 s]
# [82] train-result=0.4169, valid-result=0.9884 [0.1 s]
# [83] train-result=0.4223, valid-result=0.9887 [0.3 s]
# [84] train-result=0.4162, valid-result=0.9866 [0.2 s]
# [85] train-result=0.4094, valid-result=0.9841 [0.1 s]
# [86] train-result=0.4069, valid-result=0.9806 [0.1 s]
# [87] train-result=0.4027, valid-result=0.9798 [0.1 s]
# [88] train-result=0.4034, valid-result=0.9778 [0.1 s]
# [89] train-result=0.4033, valid-result=0.9775 [0.1 s]
# [90] train-result=0.3964, valid-result=0.9741 [0.1 s]
# [91] train-result=0.3924, valid-result=0.9722 [0.1 s]
# [92] train-result=0.3907, valid-result=0.9697 [0.1 s]
# [93] train-result=0.3949, valid-result=0.9743 [0.1 s]
# [94] train-result=0.3866, valid-result=0.9668 [0.1 s]
# [95] train-result=0.3994, valid-result=0.9741 [0.1 s]
# [96] train-result=0.3840, valid-result=0.9667 [0.1 s]
# [97] train-result=0.3818, valid-result=0.9652 [0.1 s]
# [98] train-result=0.3786, valid-result=0.9629 [0.1 s]
# [99] train-result=0.3770, valid-result=0.9638 [0.1 s]
# [100] train-result=0.3762, valid-result=0.9604 [0.1 s]
# [101] train-result=0.3756, valid-result=0.9617 [0.1 s]
# [102] train-result=0.3739, valid-result=0.9593 [0.1 s]
# [103] train-result=0.3813, valid-result=0.9623 [0.1 s]
# [104] train-result=0.3657, valid-result=0.9572 [0.1 s]
# [105] train-result=0.3625, valid-result=0.9572 [0.1 s]
# [106] train-result=0.3610, valid-result=0.9536 [0.1 s]
# [107] train-result=0.3613, valid-result=0.9506 [0.1 s]
# [108] train-result=0.3605, valid-result=0.9553 [0.1 s]
# [109] train-result=0.3554, valid-result=0.9537 [0.1 s]
# [110] train-result=0.3516, valid-result=0.9493 [0.1 s]
# [111] train-result=0.3491, valid-result=0.9472 [0.1 s]
# [112] train-result=0.3493, valid-result=0.9458 [0.1 s]
# [113] train-result=0.3436, valid-result=0.9475 [0.1 s]
# [114] train-result=0.3470, valid-result=0.9458 [0.1 s]
# [115] train-result=0.3418, valid-result=0.9432 [0.1 s]
# [116] train-result=0.3443, valid-result=0.9414 [0.1 s]
# [117] train-result=0.3446, valid-result=0.9407 [0.1 s]
# [118] train-result=0.3347, valid-result=0.9398 [0.1 s]
# [119] train-result=0.3332, valid-result=0.9365 [0.1 s]
# [120] train-result=0.3349, valid-result=0.9367 [0.1 s]
# [121] train-result=0.3300, valid-result=0.9342 [0.1 s]
# [122] train-result=0.3261, valid-result=0.9320 [0.1 s]
# [123] train-result=0.3308, valid-result=0.9309 [0.1 s]
# [124] train-result=0.3291, valid-result=0.9292 [0.1 s]
# [125] train-result=0.3220, valid-result=0.9272 [0.1 s]
# [126] train-result=0.3277, valid-result=0.9285 [0.1 s]
# [127] train-result=0.3164, valid-result=0.9224 [0.1 s]
# [128] train-result=0.3199, valid-result=0.9236 [0.1 s]
# [129] train-result=0.3146, valid-result=0.9240 [0.1 s]
# [130] train-result=0.3100, valid-result=0.9200 [0.1 s]
# [131] train-result=0.3063, valid-result=0.9172 [0.1 s]
# [132] train-result=0.3116, valid-result=0.9187 [0.1 s]
# [133] train-result=0.3095, valid-result=0.9177 [0.1 s]
# [134] train-result=0.3002, valid-result=0.9147 [0.1 s]
# [135] train-result=0.2993, valid-result=0.9117 [0.1 s]
# [136] train-result=0.3001, valid-result=0.9106 [0.1 s]
# [137] train-result=0.2937, valid-result=0.9074 [0.1 s]
# [138] train-result=0.2934, valid-result=0.9055 [0.1 s]
# [139] train-result=0.2921, valid-result=0.9047 [0.1 s]
# [140] train-result=0.2896, valid-result=0.9031 [0.1 s]
# [141] train-result=0.2936, valid-result=0.9022 [0.1 s]
# [142] train-result=0.2859, valid-result=0.9034 [0.1 s]
# [143] train-result=0.2893, valid-result=0.8982 [0.1 s]
# [144] train-result=0.2837, valid-result=0.8970 [0.1 s]
# [145] train-result=0.2827, valid-result=0.8945 [0.1 s]
# [146] train-result=0.2800, valid-result=0.8927 [0.1 s]
# [147] train-result=0.2797, valid-result=0.8906 [0.1 s]
# [148] train-result=0.2808, valid-result=0.8894 [0.1 s]
# [149] train-result=0.2688, valid-result=0.8850 [0.1 s]
# [150] train-result=0.2664, valid-result=0.8834 [0.1 s]
# [151] train-result=0.2678, valid-result=0.8827 [0.1 s]
# [152] train-result=0.2640, valid-result=0.8779 [0.1 s]
# [153] train-result=0.2601, valid-result=0.8751 [0.1 s]
# [154] train-result=0.2594, valid-result=0.8723 [0.1 s]
# [155] train-result=0.2679, valid-result=0.8757 [0.1 s]
# [156] train-result=0.2563, valid-result=0.8704 [0.1 s]
# [157] train-result=0.2579, valid-result=0.8701 [0.1 s]
# [158] train-result=0.2489, valid-result=0.8666 [0.1 s]
# [159] train-result=0.2476, valid-result=0.8628 [0.1 s]
# [160] train-result=0.2454, valid-result=0.8616 [0.1 s]
# [161] train-result=0.2408, valid-result=0.8602 [0.1 s]
# [162] train-result=0.2402, valid-result=0.8575 [0.1 s]
# [163] train-result=0.2399, valid-result=0.8547 [0.1 s]
# [164] train-result=0.2418, valid-result=0.8523 [0.1 s]
# [165] train-result=0.2450, valid-result=0.8513 [0.1 s]
# [166] train-result=0.2315, valid-result=0.8477 [0.1 s]
# [167] train-result=0.2298, valid-result=0.8448 [0.1 s]
# [168] train-result=0.2286, valid-result=0.8422 [0.1 s]
# [169] train-result=0.2267, valid-result=0.8428 [0.1 s]
# [170] train-result=0.2373, valid-result=0.8436 [0.1 s]
# [171] train-result=0.2305, valid-result=0.8368 [0.1 s]
# [172] train-result=0.2221, valid-result=0.8353 [0.1 s]
# [173] train-result=0.2184, valid-result=0.8319 [0.1 s]
# [174] train-result=0.2225, valid-result=0.8318 [0.1 s]
# [175] train-result=0.2194, valid-result=0.8289 [0.1 s]
# [176] train-result=0.2174, valid-result=0.8287 [0.1 s]
# [177] train-result=0.2163, valid-result=0.8252 [0.1 s]
# [178] train-result=0.2143, valid-result=0.8243 [0.1 s]
# [179] train-result=0.2124, valid-result=0.8176 [0.1 s]
# [180] train-result=0.2147, valid-result=0.8190 [0.1 s]
# [181] train-result=0.2111, valid-result=0.8159 [0.1 s]
# [182] train-result=0.2210, valid-result=0.8184 [0.1 s]
# [183] train-result=0.2053, valid-result=0.8087 [0.1 s]
# [184] train-result=0.2102, valid-result=0.8090 [0.1 s]
# [185] train-result=0.2049, valid-result=0.8086 [0.1 s]
# [186] train-result=0.2009, valid-result=0.8044 [0.1 s]
# [187] train-result=0.1973, valid-result=0.7994 [0.1 s]
# [188] train-result=0.1950, valid-result=0.7972 [0.1 s]
# [189] train-result=0.1931, valid-result=0.7951 [0.1 s]
# [190] train-result=0.1920, valid-result=0.7926 [0.1 s]
# [191] train-result=0.1911, valid-result=0.7907 [0.1 s]
# [192] train-result=0.1903, valid-result=0.7891 [0.1 s]
# [193] train-result=0.1845, valid-result=0.7854 [0.1 s]
# [194] train-result=0.1846, valid-result=0.7841 [0.1 s]
# [195] train-result=0.1834, valid-result=0.7827 [0.1 s]
# [196] train-result=0.1823, valid-result=0.7804 [0.1 s]
# [197] train-result=0.1801, valid-result=0.7777 [0.1 s]
# [198] train-result=0.1781, valid-result=0.7747 [0.1 s]
# [199] train-result=0.1782, valid-result=0.7721 [0.1 s]
# [200] train-result=0.1760, valid-result=0.7709 [0.1 s]
# [201] train-result=0.1775, valid-result=0.7674 [0.1 s]
# [202] train-result=0.1719, valid-result=0.7650 [0.1 s]
# [203] train-result=0.1717, valid-result=0.7645 [0.1 s]
# [204] train-result=0.1747, valid-result=0.7629 [0.1 s]
# [205] train-result=0.1738, valid-result=0.7605 [0.1 s]
# [206] train-result=0.1696, valid-result=0.7584 [0.1 s]
# [207] train-result=0.1657, valid-result=0.7554 [0.1 s]
# [208] train-result=0.1685, valid-result=0.7535 [0.1 s]
# [209] train-result=0.1681, valid-result=0.7506 [0.1 s]
# [210] train-result=0.1658, valid-result=0.7499 [0.1 s]
# [211] train-result=0.1621, valid-result=0.7457 [0.1 s]
# [212] train-result=0.1602, valid-result=0.7462 [0.1 s]
# [213] train-result=0.1598, valid-result=0.7423 [0.1 s]
# [214] train-result=0.1564, valid-result=0.7392 [0.1 s]
# [215] train-result=0.1553, valid-result=0.7369 [0.1 s]
# [216] train-result=0.1550, valid-result=0.7362 [0.1 s]
# [217] train-result=0.1543, valid-result=0.7335 [0.1 s]
# [218] train-result=0.1543, valid-result=0.7313 [0.1 s]
# [219] train-result=0.1581, valid-result=0.7301 [0.1 s]
# [220] train-result=0.1560, valid-result=0.7298 [0.1 s]
# [221] train-result=0.1503, valid-result=0.7261 [0.1 s]
# [222] train-result=0.1538, valid-result=0.7229 [0.1 s]
# [223] train-result=0.1652, valid-result=0.7251 [0.1 s]
# [224] train-result=0.1477, valid-result=0.7177 [0.1 s]
# [225] train-result=0.1535, valid-result=0.7184 [0.1 s]
# [226] train-result=0.1468, valid-result=0.7142 [0.1 s]
# [227] train-result=0.1440, valid-result=0.7130 [0.1 s]
# [228] train-result=0.1410, valid-result=0.7094 [0.1 s]
# [229] train-result=0.1406, valid-result=0.7068 [0.1 s]
# [230] train-result=0.1399, valid-result=0.7067 [0.1 s]
# [231] train-result=0.1373, valid-result=0.7030 [0.1 s]
# [232] train-result=0.1365, valid-result=0.7016 [0.1 s]
# [233] train-result=0.1345, valid-result=0.6990 [0.1 s]
# [234] train-result=0.1384, valid-result=0.6985 [0.1 s]
# [235] train-result=0.1379, valid-result=0.6959 [0.1 s]
# [236] train-result=0.1331, valid-result=0.6938 [0.1 s]
# [237] train-result=0.1356, valid-result=0.6919 [0.1 s]
# [238] train-result=0.1393, valid-result=0.6905 [0.1 s]
# [239] train-result=0.1329, valid-result=0.6889 [0.1 s]
# [240] train-result=0.1289, valid-result=0.6858 [0.1 s]
# [241] train-result=0.1256, valid-result=0.6827 [0.1 s]
# [242] train-result=0.1251, valid-result=0.6808 [0.1 s]
# [243] train-result=0.1248, valid-result=0.6792 [0.1 s]
# [244] train-result=0.1232, valid-result=0.6785 [0.1 s]
# [245] train-result=0.1212, valid-result=0.6750 [0.1 s]
# [246] train-result=0.1223, valid-result=0.6735 [0.1 s]
# [247] train-result=0.1189, valid-result=0.6694 [0.1 s]
# [248] train-result=0.1203, valid-result=0.6700 [0.1 s]
# [249] train-result=0.1211, valid-result=0.6677 [0.1 s]
# [250] train-result=0.1177, valid-result=0.6659 [0.1 s]
# [251] train-result=0.1224, valid-result=0.6638 [0.1 s]
# [252] train-result=0.1162, valid-result=0.6619 [0.1 s]
# [253] train-result=0.1160, valid-result=0.6602 [0.1 s]
# [254] train-result=0.1155, valid-result=0.6584 [0.1 s]
# [255] train-result=0.1132, valid-result=0.6571 [0.3 s]
# [256] train-result=0.1159, valid-result=0.6545 [0.1 s]
# [257] train-result=0.1161, valid-result=0.6545 [0.1 s]
# [258] train-result=0.1129, valid-result=0.6515 [0.1 s]
# [259] train-result=0.1109, valid-result=0.6497 [0.1 s]
# [260] train-result=0.1093, valid-result=0.6482 [0.1 s]
# [261] train-result=0.1077, valid-result=0.6469 [0.1 s]
# [262] train-result=0.1085, valid-result=0.6458 [0.1 s]
# [263] train-result=0.1068, valid-result=0.6439 [0.1 s]
# [264] train-result=0.1066, valid-result=0.6425 [0.1 s]
# [265] train-result=0.1066, valid-result=0.6412 [0.1 s]
# [266] train-result=0.1063, valid-result=0.6408 [0.1 s]
# [267] train-result=0.1046, valid-result=0.6387 [0.1 s]
# [268] train-result=0.1031, valid-result=0.6380 [0.1 s]
# [269] train-result=0.1021, valid-result=0.6366 [0.1 s]
# [270] train-result=0.1020, valid-result=0.6341 [0.1 s]
# [271] train-result=0.1027, valid-result=0.6336 [0.1 s]
# [272] train-result=0.1001, valid-result=0.6321 [0.1 s]
# [273] train-result=0.1003, valid-result=0.6316 [0.1 s]
# [274] train-result=0.1019, valid-result=0.6306 [0.1 s]
# [275] train-result=0.1037, valid-result=0.6303 [0.1 s]
# [276] train-result=0.0976, valid-result=0.6274 [0.1 s]
# [277] train-result=0.0998, valid-result=0.6271 [0.1 s]
# [278] train-result=0.0973, valid-result=0.6257 [0.1 s]
# [279] train-result=0.0972, valid-result=0.6258 [0.1 s]
# [280] train-result=0.1001, valid-result=0.6253 [0.1 s]
# [281] train-result=0.0981, valid-result=0.6245 [0.1 s]
# [282] train-result=0.0955, valid-result=0.6227 [0.1 s]
# [283] train-result=0.0961, valid-result=0.6211 [0.1 s]
# [284] train-result=0.0954, valid-result=0.6206 [0.1 s]
# [285] train-result=0.0950, valid-result=0.6189 [0.1 s]
# [286] train-result=0.1003, valid-result=0.6187 [0.1 s]
# [287] train-result=0.0949, valid-result=0.6185 [0.1 s]
# [288] train-result=0.0934, valid-result=0.6169 [0.1 s]
# [289] train-result=0.0938, valid-result=0.6165 [0.1 s]
# [290] train-result=0.0945, valid-result=0.6149 [0.1 s]
# [291] train-result=0.0939, valid-result=0.6135 [0.1 s]
# [292] train-result=0.0936, valid-result=0.6145 [0.1 s]
# [293] train-result=0.0927, valid-result=0.6135 [0.1 s]
# [294] train-result=0.0912, valid-result=0.6122 [0.1 s]
# [295] train-result=0.0918, valid-result=0.6106 [0.1 s]
# [296] train-result=0.0924, valid-result=0.6110 [0.1 s]
# [297] train-result=0.0933, valid-result=0.6114 [0.1 s]
# [298] train-result=0.0917, valid-result=0.6090 [0.1 s]
# [299] train-result=0.0897, valid-result=0.6082 [0.1 s]
# [300] train-result=0.0887, valid-result=0.6077 [0.1 s]
# #params: 6728
# [1] train-result=4.7489, valid-result=4.6896 [0.2 s]
# [2] train-result=3.1820, valid-result=3.1606 [0.1 s]
# [3] train-result=3.1939, valid-result=3.1800 [0.1 s]
# [4] train-result=2.5118, valid-result=2.5902 [0.1 s]
# [5] train-result=2.3523, valid-result=2.5165 [0.1 s]
# [6] train-result=2.1827, valid-result=2.4084 [0.1 s]
# [7] train-result=2.1043, valid-result=2.3366 [0.1 s]
# [8] train-result=2.1284, valid-result=2.3402 [0.1 s]
# [9] train-result=2.0705, valid-result=2.2860 [0.1 s]
# [10] train-result=2.0564, valid-result=2.2728 [0.1 s]
# [11] train-result=2.1286, valid-result=2.3323 [0.1 s]
# [12] train-result=2.0157, valid-result=2.2500 [0.1 s]
# [13] train-result=2.0087, valid-result=2.2484 [0.1 s]
# [14] train-result=1.9997, valid-result=2.2504 [0.1 s]
# [15] train-result=1.9626, valid-result=2.2309 [0.1 s]
# [16] train-result=1.8851, valid-result=2.1781 [0.1 s]
# [17] train-result=1.8461, valid-result=2.1435 [0.1 s]
# [18] train-result=1.9011, valid-result=2.1809 [0.1 s]
# [19] train-result=1.7910, valid-result=2.0852 [0.1 s]
# [20] train-result=1.7563, valid-result=2.0549 [0.1 s]
# [21] train-result=1.7143, valid-result=2.0198 [0.1 s]
# [22] train-result=1.6645, valid-result=1.9661 [0.1 s]
# [23] train-result=1.6209, valid-result=1.9298 [0.1 s]
# [24] train-result=1.5942, valid-result=1.9081 [0.1 s]
# [25] train-result=1.5622, valid-result=1.8739 [0.1 s]
# [26] train-result=1.5273, valid-result=1.8482 [0.1 s]
# [27] train-result=1.4815, valid-result=1.8240 [0.1 s]
# [28] train-result=1.4042, valid-result=1.7584 [0.1 s]
# [29] train-result=1.4026, valid-result=1.7408 [0.1 s]
# [30] train-result=1.3935, valid-result=1.7274 [0.1 s]
# [31] train-result=1.2758, valid-result=1.6613 [0.1 s]
# [32] train-result=1.2615, valid-result=1.6307 [0.1 s]
# [33] train-result=1.2327, valid-result=1.6149 [0.1 s]
# [34] train-result=1.1637, valid-result=1.5643 [0.1 s]
# [35] train-result=1.1289, valid-result=1.5251 [0.1 s]
# [36] train-result=1.1179, valid-result=1.5146 [0.1 s]
# [37] train-result=1.0615, valid-result=1.4810 [0.1 s]
# [38] train-result=1.0334, valid-result=1.4555 [0.1 s]
# [39] train-result=1.0104, valid-result=1.4398 [0.1 s]
# [40] train-result=0.9675, valid-result=1.4033 [0.1 s]
# [41] train-result=0.9528, valid-result=1.3868 [0.1 s]
# [42] train-result=0.9387, valid-result=1.3809 [0.1 s]
# [43] train-result=0.9036, valid-result=1.3662 [0.1 s]
# [44] train-result=0.8943, valid-result=1.3564 [0.1 s]
# [45] train-result=0.8760, valid-result=1.3438 [0.1 s]
# [46] train-result=0.8696, valid-result=1.3472 [0.1 s]
# [47] train-result=0.8441, valid-result=1.3346 [0.1 s]
# [48] train-result=0.8424, valid-result=1.3256 [0.1 s]
# [49] train-result=0.8131, valid-result=1.3142 [0.1 s]
# [50] train-result=0.7862, valid-result=1.2977 [0.1 s]
# [51] train-result=0.7743, valid-result=1.2860 [0.1 s]
# [52] train-result=0.7664, valid-result=1.2824 [0.1 s]
# [53] train-result=0.7553, valid-result=1.2816 [0.1 s]
# [54] train-result=0.7546, valid-result=1.2833 [0.1 s]
# [55] train-result=0.7386, valid-result=1.2713 [0.1 s]
# [56] train-result=0.7241, valid-result=1.2674 [0.1 s]
# [57] train-result=0.7071, valid-result=1.2530 [0.1 s]
# [58] train-result=0.6996, valid-result=1.2477 [0.1 s]
# [59] train-result=0.6874, valid-result=1.2403 [0.1 s]
# [60] train-result=0.6818, valid-result=1.2318 [0.1 s]
# [61] train-result=0.6788, valid-result=1.2255 [0.1 s]
# [62] train-result=0.6696, valid-result=1.2188 [0.1 s]
# [63] train-result=0.6487, valid-result=1.2103 [0.1 s]
# [64] train-result=0.6414, valid-result=1.2062 [0.1 s]
# [65] train-result=0.6315, valid-result=1.1999 [0.1 s]
# [66] train-result=0.6225, valid-result=1.1876 [0.1 s]
# [67] train-result=0.6163, valid-result=1.1817 [0.1 s]
# [68] train-result=0.6094, valid-result=1.1765 [0.1 s]
# [69] train-result=0.6026, valid-result=1.1754 [0.1 s]
# [70] train-result=0.5927, valid-result=1.1677 [0.1 s]
# [71] train-result=0.5768, valid-result=1.1542 [0.1 s]
# [72] train-result=0.5791, valid-result=1.1528 [0.1 s]
# [73] train-result=0.5667, valid-result=1.1448 [0.1 s]
# [74] train-result=0.5562, valid-result=1.1364 [0.1 s]
# [75] train-result=0.5490, valid-result=1.1306 [0.1 s]
# [76] train-result=0.5412, valid-result=1.1209 [0.1 s]
# [77] train-result=0.5312, valid-result=1.1142 [0.1 s]
# [78] train-result=0.5277, valid-result=1.1089 [0.1 s]
# [79] train-result=0.5215, valid-result=1.1068 [0.1 s]
# [80] train-result=0.5264, valid-result=1.1060 [0.1 s]
# [81] train-result=0.5038, valid-result=1.0940 [0.1 s]
# [82] train-result=0.4994, valid-result=1.0914 [0.1 s]
# [83] train-result=0.4943, valid-result=1.0808 [0.1 s]
# [84] train-result=0.4983, valid-result=1.0795 [0.1 s]
# [85] train-result=0.4861, valid-result=1.0776 [0.1 s]
# [86] train-result=0.4784, valid-result=1.0687 [0.1 s]
# [87] train-result=0.4725, valid-result=1.0652 [0.1 s]
# [88] train-result=0.4639, valid-result=1.0544 [0.1 s]
# [89] train-result=0.4534, valid-result=1.0523 [0.1 s]
# [90] train-result=0.4610, valid-result=1.0591 [0.1 s]
# [91] train-result=0.4457, valid-result=1.0439 [0.1 s]
# [92] train-result=0.4401, valid-result=1.0400 [0.1 s]
# [93] train-result=0.4278, valid-result=1.0362 [0.1 s]
# [94] train-result=0.4212, valid-result=1.0324 [0.1 s]
# [95] train-result=0.4188, valid-result=1.0277 [0.1 s]
# [96] train-result=0.4086, valid-result=1.0225 [0.1 s]
# [97] train-result=0.4040, valid-result=1.0206 [0.1 s]
# [98] train-result=0.4056, valid-result=1.0123 [0.1 s]
# [99] train-result=0.3943, valid-result=1.0076 [0.1 s]
# [100] train-result=0.3879, valid-result=1.0066 [0.1 s]
# [101] train-result=0.3781, valid-result=1.0007 [0.1 s]
# [102] train-result=0.3689, valid-result=0.9929 [0.1 s]
# [103] train-result=0.3656, valid-result=0.9891 [0.1 s]
# [104] train-result=0.3618, valid-result=0.9862 [0.1 s]
# [105] train-result=0.3569, valid-result=0.9829 [0.1 s]
# [106] train-result=0.3475, valid-result=0.9759 [0.1 s]
# [107] train-result=0.3433, valid-result=0.9683 [0.1 s]
# [108] train-result=0.3328, valid-result=0.9621 [0.1 s]
# [109] train-result=0.3274, valid-result=0.9586 [0.1 s]
# [110] train-result=0.3256, valid-result=0.9575 [0.1 s]
# [111] train-result=0.3225, valid-result=0.9542 [0.1 s]
# [112] train-result=0.3154, valid-result=0.9428 [0.1 s]
# [113] train-result=0.3082, valid-result=0.9390 [0.1 s]
# [114] train-result=0.3003, valid-result=0.9350 [0.1 s]
# [115] train-result=0.2973, valid-result=0.9289 [0.1 s]
# [116] train-result=0.2921, valid-result=0.9189 [0.1 s]
# [117] train-result=0.2878, valid-result=0.9178 [0.1 s]
# [118] train-result=0.2826, valid-result=0.9130 [0.1 s]
# [119] train-result=0.2834, valid-result=0.9104 [0.1 s]
# [120] train-result=0.2742, valid-result=0.8969 [0.1 s]
# [121] train-result=0.2716, valid-result=0.8926 [0.1 s]
# [122] train-result=0.2699, valid-result=0.8965 [0.1 s]
# [123] train-result=0.2598, valid-result=0.8849 [0.1 s]
# [124] train-result=0.2539, valid-result=0.8793 [0.1 s]
# [125] train-result=0.2501, valid-result=0.8729 [0.1 s]
# [126] train-result=0.2449, valid-result=0.8647 [0.1 s]
# [127] train-result=0.2443, valid-result=0.8626 [0.1 s]
# [128] train-result=0.2388, valid-result=0.8564 [0.1 s]
# [129] train-result=0.2377, valid-result=0.8504 [0.1 s]
# [130] train-result=0.2314, valid-result=0.8449 [0.1 s]
# [131] train-result=0.2263, valid-result=0.8424 [0.1 s]
# [132] train-result=0.2201, valid-result=0.8355 [0.1 s]
# [133] train-result=0.2258, valid-result=0.8298 [0.1 s]
# [134] train-result=0.2162, valid-result=0.8258 [0.1 s]
# [135] train-result=0.2115, valid-result=0.8232 [0.1 s]
# [136] train-result=0.2096, valid-result=0.8185 [0.1 s]
# [137] train-result=0.2036, valid-result=0.8142 [0.1 s]
# [138] train-result=0.2017, valid-result=0.8078 [0.1 s]
# [139] train-result=0.2063, valid-result=0.8042 [0.1 s]
# [140] train-result=0.2004, valid-result=0.8026 [0.1 s]
# [141] train-result=0.1957, valid-result=0.7927 [0.1 s]
# [142] train-result=0.1920, valid-result=0.7924 [0.1 s]
# [143] train-result=0.1901, valid-result=0.7905 [0.1 s]
# [144] train-result=0.1904, valid-result=0.7829 [0.1 s]
# [145] train-result=0.1844, valid-result=0.7758 [0.1 s]
# [146] train-result=0.1804, valid-result=0.7741 [0.1 s]
# [147] train-result=0.1761, valid-result=0.7704 [0.1 s]
# [148] train-result=0.1822, valid-result=0.7744 [0.1 s]
# [149] train-result=0.1752, valid-result=0.7629 [0.1 s]
# [150] train-result=0.1718, valid-result=0.7612 [0.1 s]
# [151] train-result=0.1704, valid-result=0.7570 [0.1 s]
# [152] train-result=0.1678, valid-result=0.7531 [0.1 s]
# [153] train-result=0.1656, valid-result=0.7472 [0.1 s]
# [154] train-result=0.1617, valid-result=0.7452 [0.1 s]
# [155] train-result=0.1619, valid-result=0.7400 [0.1 s]
# [156] train-result=0.1619, valid-result=0.7392 [0.1 s]
# [157] train-result=0.1561, valid-result=0.7347 [0.1 s]
# [158] train-result=0.1547, valid-result=0.7322 [0.1 s]
# [159] train-result=0.1531, valid-result=0.7306 [0.1 s]
# [160] train-result=0.1522, valid-result=0.7252 [0.1 s]
# [161] train-result=0.1521, valid-result=0.7232 [0.1 s]
# [162] train-result=0.1482, valid-result=0.7203 [0.1 s]
# [163] train-result=0.1462, valid-result=0.7172 [0.1 s]
# [164] train-result=0.1477, valid-result=0.7147 [0.1 s]
# [165] train-result=0.1465, valid-result=0.7130 [0.1 s]
# [166] train-result=0.1476, valid-result=0.7110 [0.1 s]
# [167] train-result=0.1411, valid-result=0.7082 [0.1 s]
# [168] train-result=0.1396, valid-result=0.7041 [0.1 s]
# [169] train-result=0.1427, valid-result=0.7052 [0.1 s]
# [170] train-result=0.1386, valid-result=0.6983 [0.1 s]
# [171] train-result=0.1377, valid-result=0.6976 [0.1 s]
# [172] train-result=0.1340, valid-result=0.6937 [0.1 s]
# [173] train-result=0.1331, valid-result=0.6918 [0.1 s]
# [174] train-result=0.1331, valid-result=0.6918 [0.1 s]
# [175] train-result=0.1310, valid-result=0.6891 [0.1 s]
# [176] train-result=0.1308, valid-result=0.6848 [0.1 s]
# [177] train-result=0.1304, valid-result=0.6830 [0.1 s]
# [178] train-result=0.1299, valid-result=0.6828 [0.1 s]
# [179] train-result=0.1270, valid-result=0.6807 [0.1 s]
# [180] train-result=0.1315, valid-result=0.6774 [0.1 s]
# [181] train-result=0.1282, valid-result=0.6754 [0.1 s]
# [182] train-result=0.1268, valid-result=0.6754 [0.1 s]
# [183] train-result=0.1245, valid-result=0.6720 [0.1 s]
# [184] train-result=0.1233, valid-result=0.6712 [0.1 s]
# [185] train-result=0.1237, valid-result=0.6696 [0.1 s]
# [186] train-result=0.1223, valid-result=0.6680 [0.1 s]
# [187] train-result=0.1245, valid-result=0.6657 [0.1 s]
# [188] train-result=0.1204, valid-result=0.6655 [0.1 s]
# [189] train-result=0.1190, valid-result=0.6606 [0.1 s]
# [190] train-result=0.1187, valid-result=0.6587 [0.1 s]
# [191] train-result=0.1187, valid-result=0.6601 [0.1 s]
# [192] train-result=0.1188, valid-result=0.6590 [0.1 s]
# [193] train-result=0.1209, valid-result=0.6569 [0.1 s]
# [194] train-result=0.1148, valid-result=0.6552 [0.1 s]
# [195] train-result=0.1189, valid-result=0.6552 [0.1 s]
# [196] train-result=0.1200, valid-result=0.6519 [0.1 s]
# [197] train-result=0.1136, valid-result=0.6505 [0.1 s]
# [198] train-result=0.1117, valid-result=0.6479 [0.1 s]
# [199] train-result=0.1125, valid-result=0.6468 [0.1 s]
# [200] train-result=0.1100, valid-result=0.6455 [0.1 s]
# [201] train-result=0.1137, valid-result=0.6457 [0.1 s]
# ...
# [211] train-result=0.2780, valid-result=0.9877 [0.1 s]
# [212] train-result=0.2792, valid-result=0.9873 [0.1 s]
# [213] train-result=0.2794, valid-result=0.9834 [0.1 s]
# [214] train-result=0.2741, valid-result=0.9830 [0.1 s]
# [215] train-result=0.2710, valid-result=0.9802 [0.1 s]
# [216] train-result=0.2762, valid-result=0.9851 [0.1 s]
# [217] train-result=0.2689, valid-result=0.9786 [0.2 s]
# [218] train-result=0.2768, valid-result=0.9775 [0.2 s]
# [219] train-result=0.2738, valid-result=0.9743 [0.1 s]
# [220] train-result=0.2661, valid-result=0.9714 [0.1 s]
# [221] train-result=0.2674, valid-result=0.9734 [0.1 s]
# [222] train-result=0.2667, valid-result=0.9727 [0.1 s]
# [223] train-result=0.2615, valid-result=0.9678 [0.1 s]
# [224] train-result=0.2722, valid-result=0.9692 [0.1 s]
# [225] train-result=0.2599, valid-result=0.9628 [0.1 s]
# [226] train-result=0.2589, valid-result=0.9625 [0.1 s]
# [227] train-result=0.2545, valid-result=0.9595 [0.1 s]
# [228] train-result=0.2651, valid-result=0.9602 [0.1 s]
# [229] train-result=0.2550, valid-result=0.9558 [0.1 s]
# [230] train-result=0.2575, valid-result=0.9572 [0.1 s]
# [231] train-result=0.2499, valid-result=0.9518 [0.1 s]
# [232] train-result=0.2490, valid-result=0.9517 [0.1 s]
# [233] train-result=0.2476, valid-result=0.9477 [0.1 s]
# [234] train-result=0.2574, valid-result=0.9461 [0.1 s]
# [235] train-result=0.2459, valid-result=0.9411 [0.1 s]
# [236] train-result=0.2440, valid-result=0.9407 [0.1 s]
# [237] train-result=0.2469, valid-result=0.9412 [0.1 s]
# [238] train-result=0.2396, valid-result=0.9348 [0.1 s]
# [239] train-result=0.2397, valid-result=0.9342 [0.1 s]
# [240] train-result=0.2415, valid-result=0.9338 [0.1 s]
# [241] train-result=0.2326, valid-result=0.9293 [0.1 s]
# [242] train-result=0.2404, valid-result=0.9315 [0.1 s]
# [243] train-result=0.2320, valid-result=0.9266 [0.1 s]
# [244] train-result=0.2318, valid-result=0.9253 [0.1 s]
# [245] train-result=0.2287, valid-result=0.9214 [0.1 s]
# [246] train-result=0.2243, valid-result=0.9185 [0.1 s]
# [247] train-result=0.2236, valid-result=0.9183 [0.1 s]
# [248] train-result=0.2242, valid-result=0.9139 [0.1 s]
# [249] train-result=0.2214, valid-result=0.9117 [0.1 s]
# [250] train-result=0.2220, valid-result=0.9119 [0.1 s]
# [251] train-result=0.2192, valid-result=0.9089 [0.1 s]
# [252] train-result=0.2161, valid-result=0.9045 [0.1 s]
# [253] train-result=0.2221, valid-result=0.9038 [0.1 s]
# [254] train-result=0.2146, valid-result=0.9025 [0.1 s]
# [255] train-result=0.2156, valid-result=0.8987 [0.1 s]
# [256] train-result=0.2112, valid-result=0.8951 [0.1 s]
# [257] train-result=0.2094, valid-result=0.8927 [0.1 s]
# [258] train-result=0.2101, valid-result=0.8934 [0.1 s]
# [259] train-result=0.2062, valid-result=0.8908 [0.1 s]
# [260] train-result=0.2047, valid-result=0.8898 [0.1 s]
# [261] train-result=0.2023, valid-result=0.8835 [0.1 s]
# [262] train-result=0.2033, valid-result=0.8813 [0.2 s]
# [263] train-result=0.2020, valid-result=0.8800 [0.1 s]
# [264] train-result=0.1984, valid-result=0.8767 [0.1 s]
# [265] train-result=0.1969, valid-result=0.8749 [0.1 s]
# [266] train-result=0.1968, valid-result=0.8727 [0.1 s]
# [267] train-result=0.1965, valid-result=0.8702 [0.1 s]
# [268] train-result=0.1996, valid-result=0.8692 [0.1 s]
# [269] train-result=0.1907, valid-result=0.8647 [0.1 s]
# [270] train-result=0.1889, valid-result=0.8616 [0.1 s]
# [271] train-result=0.1943, valid-result=0.8648 [0.1 s]
# [272] train-result=0.1878, valid-result=0.8587 [0.1 s]
# [273] train-result=0.1848, valid-result=0.8552 [0.1 s]
# [274] train-result=0.1871, valid-result=0.8534 [0.1 s]
# [275] train-result=0.1833, valid-result=0.8503 [0.1 s]
# [276] train-result=0.1815, valid-result=0.8495 [0.1 s]
# [277] train-result=0.1788, valid-result=0.8440 [0.1 s]
# [278] train-result=0.1831, valid-result=0.8435 [0.1 s]
# [279] train-result=0.1818, valid-result=0.8401 [0.1 s]
# [280] train-result=0.1757, valid-result=0.8355 [0.1 s]
# [281] train-result=0.1762, valid-result=0.8356 [0.1 s]
# [282] train-result=0.1715, valid-result=0.8330 [0.1 s]
# [283] train-result=0.1748, valid-result=0.8303 [0.1 s]
# [284] train-result=0.1700, valid-result=0.8277 [0.1 s]
# [285] train-result=0.1695, valid-result=0.8234 [0.1 s]
# [286] train-result=0.1692, valid-result=0.8226 [0.1 s]
# [287] train-result=0.1649, valid-result=0.8189 [0.1 s]
# [288] train-result=0.1664, valid-result=0.8169 [0.1 s]
# [289] train-result=0.1647, valid-result=0.8171 [0.1 s]
# [290] train-result=0.1729, valid-result=0.8161 [0.1 s]
# [291] train-result=0.1655, valid-result=0.8138 [0.1 s]
# [292] train-result=0.1618, valid-result=0.8110 [0.1 s]
# [293] train-result=0.1641, valid-result=0.8065 [0.1 s]
# [294] train-result=0.1651, valid-result=0.8045 [0.1 s]
# [295] train-result=0.1548, valid-result=0.8010 [0.1 s]
# [296] train-result=0.1565, valid-result=0.7995 [0.1 s]
# [297] train-result=0.1566, valid-result=0.7964 [0.1 s]
# [298] train-result=0.1537, valid-result=0.7949 [0.1 s]
# [299] train-result=0.1509, valid-result=0.7923 [0.1 s]
# [300] train-result=0.1508, valid-result=0.7886 [0.1 s]
# #params: 6728
# [1] train-result=5.7469, valid-result=5.7394 [0.2 s]
# [2] train-result=3.5358, valid-result=3.4877 [0.1 s]
# [3] train-result=3.5083, valid-result=3.4895 [0.1 s]
# [4] train-result=2.6506, valid-result=2.6864 [0.1 s]
# [5] train-result=2.5960, valid-result=2.6878 [0.1 s]
# [6] train-result=2.1575, valid-result=2.3552 [0.1 s]
# [7] train-result=2.3239, valid-result=2.5054 [0.1 s]
# [8] train-result=2.0977, valid-result=2.3372 [0.1 s]
# [9] train-result=2.1210, valid-result=2.3587 [0.1 s]
# [10] train-result=2.1146, valid-result=2.3597 [0.1 s]
# [11] train-result=2.0777, valid-result=2.3228 [0.1 s]
# [12] train-result=2.1284, valid-result=2.3441 [0.1 s]
# [13] train-result=1.9598, valid-result=2.2228 [0.1 s]
# [14] train-result=2.0547, valid-result=2.2914 [0.1 s]
# [15] train-result=1.9807, valid-result=2.2378 [0.1 s]
# [16] train-result=1.8847, valid-result=2.1776 [0.1 s]
# [17] train-result=1.8225, valid-result=2.1373 [0.1 s]
# [18] train-result=1.8069, valid-result=2.1130 [0.1 s]
# [19] train-result=1.7391, valid-result=2.0617 [0.1 s]
# [20] train-result=1.7092, valid-result=2.0385 [0.1 s]
# [21] train-result=1.6372, valid-result=1.9739 [0.1 s]
# [22] train-result=1.5998, valid-result=1.9374 [0.1 s]
# [23] train-result=1.5546, valid-result=1.8951 [0.1 s]
# [24] train-result=1.5307, valid-result=1.8570 [0.1 s]
# [25] train-result=1.4857, valid-result=1.8167 [0.1 s]
# [26] train-result=1.4148, valid-result=1.7612 [0.1 s]
# [27] train-result=1.3797, valid-result=1.7067 [0.1 s]
# [28] train-result=1.3050, valid-result=1.6405 [0.1 s]
# [29] train-result=1.2639, valid-result=1.5912 [0.1 s]
# [30] train-result=1.2125, valid-result=1.5338 [0.1 s]
# [31] train-result=1.1370, valid-result=1.4741 [0.1 s]
# [32] train-result=1.0940, valid-result=1.4251 [0.1 s]
# [33] train-result=1.0556, valid-result=1.3828 [0.1 s]
# [34] train-result=1.0053, valid-result=1.3422 [0.1 s]
# [35] train-result=0.9599, valid-result=1.2878 [0.1 s]
# [36] train-result=0.9250, valid-result=1.2476 [0.1 s]
# [37] train-result=0.8857, valid-result=1.2103 [0.1 s]
# [38] train-result=0.8500, valid-result=1.1772 [0.1 s]
# [39] train-result=0.8144, valid-result=1.1499 [0.1 s]
# [40] train-result=0.7973, valid-result=1.1311 [0.1 s]
# [41] train-result=0.7671, valid-result=1.1135 [0.1 s]
# [42] train-result=0.7377, valid-result=1.0923 [0.1 s]
# [43] train-result=0.7174, valid-result=1.0743 [0.1 s]
# [44] train-result=0.7012, valid-result=1.0667 [0.1 s]
# [45] train-result=0.6814, valid-result=1.0539 [0.1 s]
# [46] train-result=0.6671, valid-result=1.0419 [0.1 s]
# [47] train-result=0.6573, valid-result=1.0302 [0.1 s]
# [48] train-result=0.6418, valid-result=1.0235 [0.1 s]
# [49] train-result=0.6296, valid-result=1.0172 [0.1 s]
# [50] train-result=0.6166, valid-result=1.0091 [0.1 s]
# [51] train-result=0.6112, valid-result=1.0025 [0.1 s]
# [52] train-result=0.5940, valid-result=0.9944 [0.1 s]
# [53] train-result=0.5835, valid-result=0.9857 [0.1 s]
# [54] train-result=0.5759, valid-result=0.9813 [0.1 s]
# [55] train-result=0.5716, valid-result=0.9838 [0.1 s]
# [56] train-result=0.5728, valid-result=0.9819 [0.1 s]
# [57] train-result=0.5598, valid-result=0.9790 [0.1 s]
# [58] train-result=0.5470, valid-result=0.9690 [0.1 s]
# [59] train-result=0.5406, valid-result=0.9676 [0.1 s]
# [60] train-result=0.5382, valid-result=0.9659 [0.1 s]
# [61] train-result=0.5282, valid-result=0.9612 [0.2 s]
# [62] train-result=0.5195, valid-result=0.9562 [0.3 s]
# [63] train-result=0.5137, valid-result=0.9552 [0.1 s]
# [64] train-result=0.5144, valid-result=0.9551 [0.1 s]
# [65] train-result=0.5175, valid-result=0.9606 [0.1 s]
# [66] train-result=0.4997, valid-result=0.9503 [0.1 s]
# [67] train-result=0.4971, valid-result=0.9524 [0.1 s]
# [68] train-result=0.4934, valid-result=0.9465 [0.1 s]
# [69] train-result=0.4878, valid-result=0.9459 [0.1 s]
# [70] train-result=0.4808, valid-result=0.9410 [0.1 s]
# [71] train-result=0.4777, valid-result=0.9401 [0.1 s]
# [72] train-result=0.4763, valid-result=0.9423 [0.1 s]
# [73] train-result=0.4685, valid-result=0.9380 [0.1 s]
# [74] train-result=0.4643, valid-result=0.9376 [0.1 s]
# [75] train-result=0.4633, valid-result=0.9355 [0.1 s]
# [76] train-result=0.4572, valid-result=0.9332 [0.1 s]
# [77] train-result=0.4561, valid-result=0.9332 [0.1 s]
# [78] train-result=0.4520, valid-result=0.9316 [0.1 s]
# [79] train-result=0.4481, valid-result=0.9292 [0.1 s]
# [80] train-result=0.4455, valid-result=0.9300 [0.1 s]
# [81] train-result=0.4449, valid-result=0.9322 [0.1 s]
# [82] train-result=0.4434, valid-result=0.9291 [0.1 s]
# [83] train-result=0.4349, valid-result=0.9276 [0.1 s]
# [84] train-result=0.4359, valid-result=0.9296 [0.1 s]
# [85] train-result=0.4309, valid-result=0.9283 [0.1 s]
# [86] train-result=0.4343, valid-result=0.9261 [0.1 s]
# [87] train-result=0.4246, valid-result=0.9233 [0.1 s]
# [88] train-result=0.4261, valid-result=0.9247 [0.1 s]
# [89] train-result=0.4189, valid-result=0.9197 [0.1 s]
# [90] train-result=0.4193, valid-result=0.9208 [0.1 s]
# [91] train-result=0.4148, valid-result=0.9184 [0.2 s]
# [92] train-result=0.4099, valid-result=0.9209 [0.2 s]
# [93] train-result=0.4146, valid-result=0.9203 [0.1 s]
# [94] train-result=0.4078, valid-result=0.9195 [0.1 s]
# [95] train-result=0.4056, valid-result=0.9176 [0.1 s]
# [96] train-result=0.3993, valid-result=0.9129 [0.1 s]
# [97] train-result=0.3994, valid-result=0.9163 [0.1 s]
# [98] train-result=0.4005, valid-result=0.9167 [0.1 s]
# [99] train-result=0.3948, valid-result=0.9148 [0.1 s]
# [100] train-result=0.3918, valid-result=0.9140 [0.1 s]
# [101] train-result=0.3941, valid-result=0.9155 [0.1 s]
# [102] train-result=0.3861, valid-result=0.9153 [0.1 s]
# [103] train-result=0.3868, valid-result=0.9142 [0.1 s]
# [104] train-result=0.3848, valid-result=0.9134 [0.1 s]
# [105] train-result=0.3800, valid-result=0.9146 [0.1 s]
# [106] train-result=0.3803, valid-result=0.9113 [0.1 s]
# [107] train-result=0.3892, valid-result=0.9182 [0.1 s]
# [108] train-result=0.3739, valid-result=0.9098 [0.1 s]
# [109] train-result=0.3706, valid-result=0.9105 [0.1 s]
# [110] train-result=0.3667, valid-result=0.9090 [0.1 s]
# [111] train-result=0.3695, valid-result=0.9092 [0.1 s]
# [112] train-result=0.3695, valid-result=0.9111 [0.1 s]
# [113] train-result=0.3631, valid-result=0.9082 [0.1 s]
# [114] train-result=0.3641, valid-result=0.9102 [0.1 s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-5c121b326620> in <module>
#       1 result_gammli = gammli('cold',data, meta_info,task_type , random_state=0, params=lx_params)
# ----> 2 result_deepfm, result_fm = deepfm_fm('cold',data, meta_info,task_type , random_state=0, params=deepfm_fm_params)
#       3 result_sim_re = pd.concat([result_gammli,result_deepfm,result_fm],0)
#       4
#       5 result_sim_re.to_csv('result/cold_test/reg_cold_start.csv',index=None)
#
# ~\Desktop\索信达\代码\lvxnn_0717\scripts\benchmark\deepfm_fm_test.py in deepfm_fm(wc, data, meta_info_ori, task_type, random_state, params)
#     200             return result
#     201
# --> 202         result_1 = (model_choose(True))
#     203         result_2 = (model_choose(False))
#     204
#
# ~\Desktop\索信达\代码\lvxnn_0717\scripts\benchmark\deepfm_fm_test.py in model_choose(deep)
#     158                              random_state=random_state).split(dfTrain.iloc[:,:-1].values, dfTrain.target.values))
#     159
# --> 160                 y_train_dfm, y_test_dfm = _run_base_model_dfm(dfTrain, dfTest, folds, dfm_params)
#     161
#     162                 #y_test_dfm = sy.inverse_transform(y_test_dfm.reshape(-1,1))
#
# ~\Desktop\索信达\代码\lvxnn_0717\scripts\benchmark\deepfm_fm_test.py in _run_base_model_dfm(dfTrain, dfTest, folds, dfm_params)
#      99             dfm = DeepFM(**dfm_params)
#     100
# --> 101             dfm.fit(Xi_train_, Xv_train_, y_train_, Xi_valid_, Xv_valid_, y_valid_,early_stopping=early_stopping)
#     102
#     103             y_train_meta[valid_idx,0] = dfm.predict(Xi_valid_, Xv_valid_)
#
# ~\Desktop\索信达\代码\lvxnn_0717\scripts\benchmark\deepfm\DeepFM.py in fit(self, Xi_train, Xv_train, y_train, Xi_valid, Xv_valid, y_valid, early_stopping, refit)
#     286             for i in range(total_batch):
#     287                 Xi_batch, Xv_batch, y_batch = self.get_batch(Xi_train, Xv_train, y_train, self.batch_size, i)
# --> 288                 self.fit_on_batch(Xi_batch, Xv_batch, y_batch)
#     289
#     290             # evaluate training and validation datasets
#
# ~\Desktop\索信达\代码\lvxnn_0717\scripts\benchmark\deepfm\DeepFM.py in fit_on_batch(self, Xi, Xv, y)
#     258                      self.dropout_keep_deep: self.dropout_deep,
#     259                      self.train_phase: True}
# --> 260         loss, opt = self.sess.run((self.loss, self.optimizer), feed_dict=feed_dict)
#     261         return loss
#     262
#
# ~\Anaconda3\lib\site-packages\tensorflow_core\python\client\session.py in run(self, fetches, feed_dict, options, run_metadata)
#     954     try:
#     955       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 956                          run_metadata_ptr)
#     957       if run_metadata:
#     958         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# ~\Anaconda3\lib\site-packages\tensorflow_core\python\client\session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1178     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1179       results = self._do_run(handle, final_targets, final_fetches,
# -> 1180                              feed_dict_tensor, options, run_metadata)
#    1181     else:
#    1182       results = []
#
# ~\Anaconda3\lib\site-packages\tensorflow_core\python\client\session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1357     if handle is None:
#    1358       return self._do_call(_run_fn, feeds, fetches, targets, options,
# -> 1359                            run_metadata)
#    1360     else:
#    1361       return self._do_call(_prun_fn, handle, feeds, fetches)
#
# ~\Anaconda3\lib\site-packages\tensorflow_core\python\client\session.py in _do_call(self, fn, *args)
#    1363   def _do_call(self, fn, *args):
#    1364     try:
# -> 1365       return fn(*args)
#    1366     except errors.OpError as e:
#    1367       message = compat.as_text(e.message)
#
# ~\Anaconda3\lib\site-packages\tensorflow_core\python\client\session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1348       self._extend_graph()
#    1349       return self._call_tf_sessionrun(options, feed_dict, fetch_list,
# -> 1350                                       target_list, run_metadata)
#    1351
#    1352     def _prun_fn(handle, feed_dict, fetch_list):
#
# ~\Anaconda3\lib\site-packages\tensorflow_core\python\client\session.py in _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1441     return tf_session.TF_SessionRun_wrapper(self._session, options, feed_dict,
#    1442                                             fetch_list, target_list,
# -> 1443                                             run_metadata)
#    1444
#    1445   def _call_tf_sessionprun(self, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:
